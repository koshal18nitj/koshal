# %%
import numpy as np
import seaborn as sp
import matplotlib.pyplot as ps
# %matplotlib inline 
import pandas as pd

# %%
#df=pd.read_csv('test.csv')
players_data=df.head()
##print(players_data)
Player=players_data['Player']
#print(Player)
Mat=players_data['Inns']
print(Mat)
HS=players_data['HS']
#print(HS)

ps.pie(Mat,labels=Player,autopct='%1.1f%%')
# Out:
# 0    329
# 1    287
# 2    280
# 3    286
# 4    291
# Name: Inns, dtype: object
# ([<matplotlib.patches.Wedge at 0x19468d92430>,
# ...
#  [Text(0.8401302036462376, 0.7100572096115437, 'SR Tendulkar (INDIA)'),
#   Text(-0.47319159834274527, 0.9930204989111948, 'RT Ponting (AUS)'),
#   Text(-1.0961969179385893, -0.09139101215074723, 'JH Kallis (ICC/SA)'),
#   Text(-0.3044787909329262, -1.0570206553667831, 'R Dravid (ICC/INDIA)'),
#   Text(0.8948567564020491, -0.6397119551185549, 'AN Cook (ENG)')],
#  [Text(0.4582528383524932, 0.3873039325153874, '22.3%'),
#   Text(-0.2581045081869519, 0.5416475448606517, '19.5%'),
#   Text(-0.5979255916028668, -0.04984964299131666, '19.0%'),
#   Text(-0.16607934050886883, -0.5765567211091543, '19.4%'),
#   Text(0.48810368531020853, -0.3489337937010299, '19.8%')])
